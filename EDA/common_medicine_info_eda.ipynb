# %% [markdown]
# # 📊 EDA for medications

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_csv("..//backend/Training/MasterData/common_medicine_info.csv")
print("Dataset Uploaded Sucessfully!")
# Out:
# Dataset Uploaded Sucessfully!

# %% [markdown]
# ## 🔎 Dataset Overview

# %%
print("🔹 Dataset Shape:", df.shape)
display(df.head())
# Out:
# 🔹 Dataset Shape: (50, 3)
#    Medicine Name         Uses                                 \
# 0  Paracetamol           Fever and pain relief
# 1  Ibuprofen             Inflammation and pain relief
# 2  Cetirizine            Allergy relief
# 3  Omeprazole            Acid reflux and heartburn
# 4  Loratadine            Allergy relief
#
#                              Precautions
# 0       Do not exceed recommended dosage
# 1  Take with food to avoid stomach upset
# 2                   May cause drowsiness
# 3                      Take before meals
# 4                     Non-drowsy formula

# %%
print("\n🔹 Info:")
df.info()
# Out:
# 🔹 Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Medicine Name                        50 non-null     object
#  1   Uses                                 50 non-null     object
#  2   Precautions                          50 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
print("\n🔹 Column Names:", df.columns.tolist())
print("\n🔹 Data Types:\n", df.dtypes)
print("\n🔹 Missing Values:\n", df.isnull().sum())
print("\n🔹 Duplicate Rows:", df.duplicated().sum())
# Out:
# 🔹 Column Names: ['Medicine Name       ', 'Uses                               ', 'Precautions']
#
# 🔹 Data Types:
#  Medicine Name                          object
# Uses                                   object
# Precautions                            object
# dtype: object
#
# 🔹 Missing Values:
#  Medicine Name                          0
# Uses                                   0
# Precautions                            0
# dtype: int64
#
# 🔹 Duplicate Rows: 0

# %%
# Unique values per column
print("\n🔹 Unique Value Counts:")
print(df.nunique())
# Out:
# 🔹 Unique Value Counts:
# Medicine Name                          50
# Uses                                   35
# Precautions                            40
# dtype: int64

# %%
print("\n🔹 Descriptive Statistics:")
display(df.describe(include="all").transpose())
# Out:
# 🔹 Descriptive Statistics:
#                                     count unique  \
# Medicine Name                          50     50
# Uses                                   50     35
# Precautions                            50     40
#
#                                                                      top freq
# Medicine Name                                       Paracetamol             1
# Uses                                 Asthma and allergies                   3
# Precautions                                     Complete the full course    4

# %%
print("\n=== Univariate Analysis ===")

for col in df.columns:
    plt.figure(figsize=(8,6))
    if df[col].dtype == 'object':
        top_vals = df[col].value_counts().head(20)
        sns.barplot(y=top_vals.index, x=top_vals.values, palette="viridis")
        plt.title(f"Top 20 categories in {col}")
        plt.xlabel("Count")
        plt.ylabel(col)
        plt.show()
    else:
        sns.histplot(df[col], kde=True, bins=30, color="royalblue")
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.show()
# Out:
# === Univariate Analysis ===
# C:\Users\hp\AppData\Local\Temp\ipykernel_9592\1509616485.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_vals.index, x=top_vals.values, palette="viridis")
# C:\Users\hp\AppData\Local\Temp\ipykernel_9592\1509616485.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_vals.index, x=top_vals.values, palette="viridis")
# C:\Users\hp\AppData\Local\Temp\ipykernel_9592\1509616485.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_vals.index, x=top_vals.values, palette="viridis")

# %%
# Correlation Heatmap
numeric_cols = df.select_dtypes(include=[np.number]).columns
if len(numeric_cols) > 1:
    plt.figure(figsize=(10,6))
    corr = df[numeric_cols].corr()
    sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
    plt.title("Correlation Heatmap")
    plt.show()

# %%
# Crosstab for categorical columns
cat_cols = df.select_dtypes(include=['object']).columns
if len(cat_cols) >= 2:
    for i in range(len(cat_cols)-1):
        ct = pd.crosstab(df[cat_cols[i]], df[cat_cols[i+1]])
        print(f"\n🔹 Crosstab between {cat_cols[i]} and {cat_cols[i+1]}:\n", ct.head())
# Out:
# 🔹 Crosstab between Medicine Name        and Uses                               :
#  Uses                                 Acid reflux                          \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Acid reflux and heartburn            \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Acid reflux and ulcers               \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Acne                                 \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Allergy relief                       \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Anxiety                              \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             1
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Anxiety and muscle spasms            \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Asthma                               \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Asthma and allergies                 \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Bacterial infections                 ...  \
# Medicine Name                                                             ...
# Acyclovir                                                              0  ...
# Alprazolam                                                             0  ...
# Amlodipine                                                             0  ...
# Amoxicillin                                                            1  ...
# Aspirin                                                                0  ...
#
# Uses                                 Inflammation and pain relief         \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Influenza                            \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Insomnia                             \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Neuropathic pain                     \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Pain relief                          \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Pain relief and blood thinning       \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                1
#
# Uses                                 Severe pain                          \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Skin conditions                      \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Thyroid hormone replacement          \
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# Uses                                 Type 2 diabetes
# Medicine Name
# Acyclovir                                                              0
# Alprazolam                                                             0
# Amlodipine                                                             0
# Amoxicillin                                                            0
# Aspirin                                                                0
#
# [5 rows x 35 columns]
#
# 🔹 Crosstab between Uses                                and Precautions:
#  Precautions                          Avoid alcohol  Avoid grapefruit  \
# Uses
# Acid reflux                                      0                 0
# Acid reflux and heartburn                        0                 0
# Acid reflux and ulcers                           0                 0
# Acne                                             0                 0
# Allergy relief                                   0                 0
#
# Precautions                          Avoid in children  Avoid on broken skin  \
# Uses
# Acid reflux                                          0                     0
# Acid reflux and heartburn                            0                     0
# Acid reflux and ulcers                               0                     0
# Acne                                                 0                     0
# Allergy relief                                       0                     0
#
# Precautions                          Avoid sunlight exposure  \
# Uses
# Acid reflux                                                0
# Acid reflux and heartburn                                  0
# Acid reflux and ulcers                                     0
# Acne                                                       0
# Allergy relief                                             0
#
# Precautions                          Avoid with certain stomach medications  \
# Uses
# Acid reflux                                                               0
# Acid reflux and heartburn                                                 0
# Acid reflux and ulcers                                                    0
# Acne                                                                      0
# Allergy relief                                                            0
#
# Precautions                          Complete the full course  \
# Uses
# Acid reflux                                                 0
# Acid reflux and heartburn                                   0
# Acid reflux and ulcers                                      0
# Acne                                                        0
# Allergy relief                                              0
#
# Precautions                          Discontinued in some regions  \
# Uses
# Acid reflux                                                     0
# Acid reflux and heartburn                                       0
# Acid reflux and ulcers                                          1
# Acne                                                            0
# Allergy relief                                                  0
#
# Precautions                          Do not exceed recommended dosage  \
# Uses
# Acid reflux                                                         0
# Acid reflux and heartburn                                           0
# Acid reflux and ulcers                                              0
# Acne                                                                0
# Allergy relief                                                      0
#
# Precautions                          Do not stop abruptly  ...  \
# Uses                                                       ...
# Acid reflux                                             0  ...
# Acid reflux and heartburn                               0  ...
# Acid reflux and ulcers                                  0  ...
# Acne                                                    0  ...
# Allergy relief                                          0  ...
#
# Precautions                          Rinse mouth after use  \
# Uses
# Acid reflux                                              0
# Acid reflux and heartburn                                0
# Acid reflux and ulcers                                   0
# Acne                                                     0
# Allergy relief                                           0
#
# Precautions                          Short-term use only  \
# Uses
# Acid reflux                                            0
# Acid reflux and heartburn                              0
# Acid reflux and ulcers                                 0
# Acne                                                   0
# Allergy relief                                         0
#
# Precautions                          Start at first sign of outbreak  \
# Uses
# Acid reflux                                                        0
# Acid reflux and heartburn                                          0
# Acid reflux and ulcers                                             0
# Acne                                                               0
# Allergy relief                                                     0
#
# Precautions                          Start within 48 hours of symptoms  \
# Uses
# Acid reflux                                                          0
# Acid reflux and heartburn                                            0
# Acid reflux and ulcers                                               0
# Acne                                                                 0
# Allergy relief                                                       0
#
# Precautions                          Take before meals  Take in the evening  \
# Uses
# Acid reflux                                          0                    0
# Acid reflux and heartburn                            1                    0
# Acid reflux and ulcers                               0                    0
# Acne                                                 0                    0
# Allergy relief                                       0                    0
#
# Precautions                          Take on an empty stomach  \
# Uses
# Acid reflux                                                 0
# Acid reflux and heartburn                                   0
# Acid reflux and ulcers                                      0
# Acne                                                        0
# Allergy relief                                              0
#
# Precautions                          Take with food to avoid stomach upset  \
# Uses
# Acid reflux                                                              0
# Acid reflux and heartburn                                                0
# Acid reflux and ulcers                                                   0
# Acne                                                                     0
# Allergy relief                                                           0
#
# Precautions                          Taper dose gradually  \
# Uses
# Acid reflux                                             0
# Acid reflux and heartburn                               0
# Acid reflux and ulcers                                  0
# Acne                                                    0
# Allergy relief                                          0
#
# Precautions                          Use as directed for acute symptoms
# Uses
# Acid reflux                                                           0
# Acid reflux and heartburn                                             0
# Acid reflux and ulcers                                                0
# Acne                                                                  0
# Allergy relief                                                        0
#
# [5 rows x 40 columns]

# %%
print("\n=== Boxplots for Each Feature ===")

for col in df.columns:
    plt.figure(figsize=(7,4))
    if df[col].dtype != 'object':  # numeric features
        sns.boxplot(x=df[col], color="orange")
        plt.title(f"Boxplot of {col}")
        plt.xlabel(col)
        plt.show()
    else:  # categorical features (frequency counts as boxplot)
        top_vals = df[col].value_counts().head(10)
        sns.boxplot(x=top_vals.values, color="lightblue")
        plt.title(f"Boxplot of {col} (Top 10 frequencies)")
        plt.xlabel("Frequency")
        plt.show()
# Out:
# === Boxplots for Each Feature ===

# %%
# Missing Data Visualization
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ### EDA Completed Successfully!
